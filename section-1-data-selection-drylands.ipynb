# %%
# New notebook

import pandas as pd
import numpy as np

# %% [markdown]
# 1) Archive Exploration

# %% [markdown]
# - a) This data contain information about the environmental factors for all arthropod prey of listed species
# - b) This dataset is a synthesis of multiple datasets
# - c) From January 20, 1946 to November 7th 2022
# - d) Yes it does
# - e) no? position?

# %%
metadata_df = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A3baf7289-bf90-4db3-ad11-58785c09b26e')
metadata_df
# Out:
#                         attribute  \
# 0                           class
# 1                           order
# 2                          family
# 3                           genus
# 4                         species
# 5                             lat
# 6                            long
# 7                       eventDate
# 8                             day
# 9                           month
# 10                           year
# 11                institutionCode
# 12  coordinateUncertaintyInMeters
# 13                  basisOfRecord
# 14                individualCount
# 15                     datasetKey
# 16                           bio1
# 17                          bio10
# 18                          bio11
# 19                          bio12
# 20                          bio13
# 21                          bio14
# 22                          bio15
# 23                          bio16
# 24                          bio17
# 25                          bio18
# ...

# %%
prey = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A23d42528-1048-45d4-85d1-7e13b666e744')
df
# Out:
#                class        order           family          genus  \
# 0            Insecta      Odonata     Libellulidae      Sympetrum
# 1       Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2            Insecta  Hymenoptera           Apidae         Bombus
# 3            Insecta  Hymenoptera           Apidae           Apis
# 4            Insecta    Hemiptera        Lygaeidae     Oncopeltus
# ...              ...          ...              ...            ...
# 111151       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111152       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111153       Insecta  Hymenoptera       Formicidae     Liometopum
# 111154       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111155       Insecta  Lepidoptera      Nymphalidae        Vanessa
#
#                           species        lat        long  \
# 0             Sympetrum corruptum  37.173971 -121.856329
# ...

# %%
type(prey)
# Out:
# pandas.core.frame.DataFrame

# %%
prey
#gives min and max
# Out:
#                class        order           family          genus  \
# 0            Insecta      Odonata     Libellulidae      Sympetrum
# 1       Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2            Insecta  Hymenoptera           Apidae         Bombus
# 3            Insecta  Hymenoptera           Apidae           Apis
# 4            Insecta    Hemiptera        Lygaeidae     Oncopeltus
# ...              ...          ...              ...            ...
# 111151       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111152       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111153       Insecta  Hymenoptera       Formicidae     Liometopum
# 111154       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111155       Insecta  Lepidoptera      Nymphalidae        Vanessa
#
#                           species        lat        long  \
# 0             Sympetrum corruptum  37.173971 -121.856329
# ...

# %%
# Shows us all columns
pd.set_option("display.max.columns",None)
prey
# Out:
#                class        order           family          genus  \
# 0            Insecta      Odonata     Libellulidae      Sympetrum
# 1       Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2            Insecta  Hymenoptera           Apidae         Bombus
# 3            Insecta  Hymenoptera           Apidae           Apis
# 4            Insecta    Hemiptera        Lygaeidae     Oncopeltus
# ...              ...          ...              ...            ...
# 111151       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111152       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111153       Insecta  Hymenoptera       Formicidae     Liometopum
# 111154       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111155       Insecta  Lepidoptera      Nymphalidae        Vanessa
#
#                           species        lat        long  \
# 0             Sympetrum corruptum  37.173971 -121.856329
# ...

# %%
for col in prey:
    print(col)
# Out:
# class
# order
# family
# genus
# species
# lat
# long
# eventDate
# day
# month
# year
# institutionCode
# coordinateUncertaintyInMeters
# basisOfRecord
# individualCount
# datasetKey
# ID
# bio1
# bio10
# bio11
# bio12
# bio13
# bio14
# bio15
# bio16
# bio17
# bio18
# bio19
# bio2
# bio3
# bio4
# bio5
# bio6
# bio7
# bio8
# bio9
# dist
# dem90_hf
# lc_class
# ndvi

# %%
df['species'].dtype
# Out:
# dtype('O')

# %%
df.shape
# Out:
# (111156, 40)

# %%
print(df['month'].min())
print(df['day'].min())

print(df['month'].max())
print(df['day'].max())

print(df['year'].min())
print(df['year'].max())
# Out:
# 1.0
# 1.0
# 12.0
# 31.0
# 1946
# 2022

# %%
early_year_df = df.loc[df['year'] == 1946]
early_month_df = early_year_df.loc[early_year_df['month'] == 1]
early_month_df
# Out:
#          class        order         family       genus  \
# 40437  Insecta  Hymenoptera     Formicidae  Liometopum
# 98816  Insecta   Coleoptera  Tenebrionidae      Coelus
#
#                       species        lat       long             eventDate  \
# 40437  Liometopum occidentale  34.433334 -119.26667  1946-01-20T00:00:00Z
# 98816         Coelus ciliatus  37.776500 -122.42010  1946-01-31T00:00:00Z
#
#         day  month  ...         bio4        bio5       bio6        bio7  \
# 40437  20.0    1.0  ...  3948.708008  297.127380  32.842457  264.284912
# 98816  31.0    1.0  ...  2323.016113  219.255463  70.177017  149.078445
#
#              bio8        bio9      dist    dem90_hf   lc_class         ndvi
# 40437  113.021629  203.437531  0.643320  241.345947  grassland  5456.707520
# 98816  109.902733  161.932327  0.369647   26.539448      urban  1362.293579
#
# [2 rows x 40 columns]

# %%
latest_year_df = df.loc[df['year'] == 2022]
latest_month_df = latest_year_df.loc[latest_year_df['month'] == 11]
latest_day_df = latest_month_df.loc[latest_month_df['day'] >= 7]
latest_day_df
# Out:
#                class        order         family         genus  \
# 6450         Insecta  Lepidoptera    Nymphalidae       Vanessa
# 11349        Insecta  Hymenoptera         Apidae          Apis
# 13517        Insecta  Lepidoptera     Sphingidae         Hyles
# 13851        Insecta  Lepidoptera     Sphingidae         Hyles
# 15053        Insecta  Hymenoptera         Apidae          Apis
# 15573        Insecta  Lepidoptera    Nymphalidae       Vanessa
# 16271        Insecta  Hymenoptera         Apidae        Bombus
# 21089        Insecta   Coleoptera  Coccinellidae    Hippodamia
# 21184        Insecta      Odonata      Aeshnidae          Anax
# 29799      Arachnida      Araneae    Theridiidae   Latrodectus
# 32780        Insecta  Hymenoptera         Apidae          Apis
# 34666   Malacostraca     Decapoda      Grapsidae  Pachygrapsus
# 35030      Arachnida      Araneae    Theridiidae   Latrodectus
# 70108        Insecta    Hemiptera     Rhopalidae        Jadera
# ...
